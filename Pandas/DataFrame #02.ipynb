# %%
import numpy as np
import pandas as pd

# %%
from numpy.random import randn

np.random.seed(101)

df = pd.DataFrame(randn(5,4) , ['A','B','C','D','E'],['M','N','O','P'])

# %%
df
# Out:
#           M         N         O         P
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
dfd = df > 1
dfd
# Out:
#        M      N      O      P
# A   True  False  False  False
# B  False  False  False  False
# C  False  False  False  False
# D  False  False  False  False
# E  False   True   True  False

# %%
df[dfd]
# Out:
#          M         N         O   P
# A  2.70685       NaN       NaN NaN
# B      NaN       NaN       NaN NaN
# C      NaN       NaN       NaN NaN
# D      NaN       NaN       NaN NaN
# E      NaN  1.978757  2.605967 NaN

# %%
df
# Out:
#           M         N         O         P
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df['M'] > 0
# Out:
# A     True
# B     True
# C    False
# D     True
# E     True
# Name: M, dtype: bool

# %%
df['M']
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: M, dtype: float64

# %%
df[df['M']>0]   # excludes complete row from DataFrame which is >0.
# Out:
#           M         N         O         P
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           M         N         O         P
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[df['N']>0]
# Out:
#           M         N         O         P
# A  2.706850  0.628133  0.907969  0.503826
# C -2.018168  0.740122  0.528813 -0.589001
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[df['P']<0]
# Out:
#           M         N         O         P
# C -2.018168  0.740122  0.528813 -0.589001

# %%
result = df[df['M']>0]
result
# Out:
#           M         N         O         P
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
result['P']
# Out:
# A    0.503826
# B    0.605965
# D    0.955057
# E    0.683509
# Name: P, dtype: float64

# %%
# alternative command for above two commands

df[df['M']>0]['P']
# Out:
# A    0.503826
# B    0.605965
# D    0.955057
# E    0.683509
# Name: P, dtype: float64

# %%
df[df['M']>0][['N','P']]
# Out:
#           N         P
# A  0.628133  0.503826
# B -0.319318  0.605965
# D -0.758872  0.955057
# E  1.978757  0.683509

# %%
df[(df['M']>0) & (df['P']>0)]
# Out:
#           M         N         O         P
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[(df['M']>0) | (df['P']>0)]
# Out:
#           M         N         O         P
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           M         N         O         P
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.reset_index()
# Out:
#   index         M         N         O         P
# 0     A  2.706850  0.628133  0.907969  0.503826
# 1     B  0.651118 -0.319318 -0.848077  0.605965
# 2     C -2.018168  0.740122  0.528813 -0.589001
# 3     D  0.188695 -0.758872 -0.933237  0.955057
# 4     E  0.190794  1.978757  2.605967  0.683509

# %%
df.reset_index(col_level = 3)
# Out:
#   index         M         N         O         P
# 0     A  2.706850  0.628133  0.907969  0.503826
# 1     B  0.651118 -0.319318 -0.848077  0.605965
# 2     C -2.018168  0.740122  0.528813 -0.589001
# 3     D  0.188695 -0.758872 -0.933237  0.955057
# 4     E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           M         N         O         P
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
arr = 'PA KI ST AN ZI '.split()
arr
# Out:
# ['PA', 'KI', 'ST', 'AN', 'ZI']

# %%
df['Codes'] = arr

# %%
df
# Out:
#           M         N         O         P Codes
# A  2.706850  0.628133  0.907969  0.503826    PA
# B  0.651118 -0.319318 -0.848077  0.605965    KI
# C -2.018168  0.740122  0.528813 -0.589001    ST
# D  0.188695 -0.758872 -0.933237  0.955057    AN
# E  0.190794  1.978757  2.605967  0.683509    ZI

# %%
df.set_index('Codes')
# Out:
#               M         N         O         P
# Codes
# PA     2.706850  0.628133  0.907969  0.503826
# KI     0.651118 -0.319318 -0.848077  0.605965
# ST    -2.018168  0.740122  0.528813 -0.589001
# AN     0.188695 -0.758872 -0.933237  0.955057
# ZI     0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           M         N         O         P Codes
# A  2.706850  0.628133  0.907969  0.503826    PA
# B  0.651118 -0.319318 -0.848077  0.605965    KI
# C -2.018168  0.740122  0.528813 -0.589001    ST
# D  0.188695 -0.758872 -0.933237  0.955057    AN
# E  0.190794  1.978757  2.605967  0.683509    ZI
