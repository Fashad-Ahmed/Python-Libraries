# %%
import numpy as np

# %%
from skimage import io

# %%
photo = io.imread('https://source.unsplash.com/random')
type(photo)
# Out:
# numpy.ndarray

# %%
photo.shape
# Out:
# (720, 1080, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(photo)

# %%
plt.imshow(photo[::-1])

# %%
plt.imshow(photo[:,::-1])

# %%
plt.imshow(photo[0:400,200:800])

# %%
plt.imshow(photo[::2,::2])

# %%
plt.imshow(photo[::3,::3])

# %%
print(np.sin(photo))
# Out:
# [[[-0.757    0.412   -0.5366 ]
#   [-0.757    0.412   -0.5366 ]
#   [-0.757    0.412   -0.5366 ]
#   ...
#   [ 0.       0.8364   0.2964 ]
#   [ 0.       0.8364   0.2964 ]
#   [ 0.       0.8364   0.2964 ]]
#
#  [[-0.757    0.412   -0.5366 ]
#   [-0.757    0.412   -0.5366 ]
#   [-0.757    0.412   -0.5366 ]
#   ...
#   [-0.757   -0.846    0.745  ]
#   [-0.757   -0.846    0.745  ]
#   [ 0.1411  -0.00885  0.964  ]]
#
#  [[-0.757   -0.544   -0.544  ]
#   [-0.757   -0.544   -0.544  ]
#   [-0.757    0.412   -0.5366 ]
#   ...
#   [ 0.657   -0.1323   0.964  ]
#   [ 0.657   -0.1323   0.964  ]
#   [-0.2793  -0.906    0.2964 ]]
#
#  ...
#
#  [[ 0.      -0.5366   0.7627 ]
#   [ 0.      -0.5366   0.7627 ]
#   [ 0.      -0.5366   0.7627 ]
#   ...
#   [-0.2878  -0.5366   0.412  ]
#   [-0.2878  -0.5366   0.412  ]
#   [-0.2878  -0.5366   0.412  ]]
#
#  [[ 0.       0.4202  -0.00885]
#   [ 0.       0.4202  -0.00885]
#   [ 0.       0.4202  -0.00885]
#   ...
#   [-0.9614   0.4202  -0.544  ]
#   [-0.9614   0.4202  -0.544  ]
#   [-0.9614   0.4202  -0.544  ]]
#
#  [[ 0.       0.4202   0.8364 ]
#   [ 0.       0.4202   0.8364 ]
#   [ 0.       0.4202   0.8364 ]
#   ...
#   [-0.751    0.9907  -1.     ]
#   [-0.9614   0.4202  -0.544  ]
#   [-0.9614   0.4202  -0.544  ]]]

# %%
print(np.std(photo))
# Out:
# 68.43614049385155

# %%
print(np.var(photo))
# Out:
# 4683.505325694189

# %%
phMasked = np.where( photo > 100, 240, 2)
plt.imshow(phMasked)

# %% [markdown]
# ### Dot Product

# %%
a = [1,2,6,7]
b = np.array(a*10)
b @ b
# Out:
# 900

# %% [markdown]
# ### Transpose

# %%
plt.imshow(photo[:,:,0].T)
