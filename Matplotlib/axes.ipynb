# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(5, 10, 5)
y = x ** 2

# %%
x
# Out:
# array([ 5.  ,  6.25,  7.5 ,  8.75, 10.  ])

# %%
y
# Out:
# array([ 25.    ,  39.0625,  56.25  ,  76.5625, 100.    ])

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)

# for i in axes:
axes.plot(x,y,'r')

# %%
axes
# Out:
# <AxesSubplot:>

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

axes[0].plot(x,y) 
axes[1].plot(y,x) 

plt.tight_layout()

# %%
axes
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
fig = plt.figure(figsize=(3,2))
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig = plt.subplots(nrows=2, ncols=1, figsize=(8,3))
axes[0].plot(x,y)
axes[1].plot(y,x)
plt.tight_layout()

fig.savefig('pic.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-e40e5f586ab6> in <module>
#       4 plt.tight_layout()
#       5
# ----> 6 fig.savefig('pic.png')
#
# AttributeError: 'tuple' object has no attribute 'savefig'
